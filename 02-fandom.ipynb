# %% [markdown]
# # Hitchhikers fandom dataset creation
#
# I am attempting to compile a database of fictional world elements from the Hitchhiker's Guide to the Galaxy universe. This database will be used to generate new stories in this universe with the help of large text models. My focus is on feeding information about the universe rather than the story itself. My hope is that by doing so, I will be able to create divergent content that differs from the original corpus.

# %% [markdown]
# ## Dependencies and utilities

# %%
# !pip install python-slugify fuzzywuzzy mwparserfromhell
# Out:
# Collecting python-slugify
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting mwparserfromhell
#   Downloading mwparserfromhell-0.6.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: text-unidecode, fuzzywuzzy, python-slugify, mwparserfromhell
# Successfully installed fuzzywuzzy-0.18.0 mwparserfromhell-0.6.4 python-slugify-8.0.1 text-unidecode-1.3

# %%
from bs4 import BeautifulSoup
import requests
import os
from slugify import slugify
from fuzzywuzzy import fuzz
import mwparserfromhell
# Out:
# /opt/conda/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def print_breadcrumb(node):
    acc = ""
    for parent in node.parents:
        if parent.name:
            acc =  parent.name + " → " + acc  
    print(acc)

# %% [markdown]
# ## Main page

# %%
url = "https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(book)"
r = requests.get(url)
html_content = r.content
soup = BeautifulSoup(html_content, 'html.parser')

# %%
header_tags = ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']

# %%
main_text = soup.find(id = "mw-content-text")
headers = main_text.find_all(header_tags)

# %%
# Filter intro headers that I'm not interested in
startIdx = next((i for i, h in enumerate(headers) if h.text == "Appearances"), None)
headers = headers[startIdx:]

# %%
base = "https://hitchhikers.fandom.com/wiki"

last_seen_header = ""

def visit_node(node):
    global last_seen_header;
    global start_offset_reached;
    
    if node.name in header_tags:
        last_seen_header = node.text
    
    if node.name == "a" and len(node.text.strip()) > 0:
        fn = slugify(last_seen_header) + os.sep + slugify(node.text) + ".txt"
        print(fn)
        print(node.get('href'))
        # todo - parse
    
    for child in node.children:
        if child.name is not None:
            visit_node(child)

# %% [markdown]
# ## Getting content from a single page

# %%
def text_from_wiki(content):
    res = ""
    wikicode = mwparserfromhell.parse(content)
    sections = wikicode.get_sections()

    skip_titles = ["Notes and references", "Behind the scenes", "Appearances"]
    
    for section in sections:
        heading_nodes = section.filter_headings()

        if len(heading_nodes) == 0:
            title = "Unnamed section"
        else:
            title = heading_nodes[0].title.strip()

        text = section.strip()
        text = section.strip_code()
        if title not in skip_titles:
            res = res + text

    return res

# %%
def text_from_url(url):
    url = url + "?action=edit"
    
    r = requests.get(url)
    html_content = r.content
    marvin_soup = BeautifulSoup(html_content, 'html.parser')
    
    content_el = marvin_soup.find(id = "wpTextbox1")
    return text_from_wiki(content_el.text)

# %% [markdown]
# ## Traversing the link list page
#
# Should save the entire fandom wiki

# %%
url = "https://hitchhikers.fandom.com/wiki/Special:AllPages?from=Hotblack+Desiato%27s+bodyguard"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
content_el = soup.find(class_ = "mw-allpages-body")

# %%
link_names = [ {"fn": "data/dump" + os.sep + slugify(linkNode.text), "href": base + linkNode.get("href")} for linkNode in content_el.find_all("a")]

# %%
text_from_url("https://hitchhikers.fandom.com/wiki/Hrarf-Hrarf")
# Out:
# "The Hrarf-Hrarf are a species which live backwards in time. They are said to find that getting the business of “sagging bottoms and death” out of the way at an early stage prepares them for an increasingly wonderful time after mid-life crisis celebrations. Their lives finish in a “really quite extraordinarily pleasant birth.” They were first mentioned in Life, the Universe and Everything.\n\nThe Hrarf-Hrarf are the only known race which enjoys hangovers, as for them it guarantees that a tremendously good evening will follow.\xa0\n\nWhen Arthur Dent found himself on prehistoric Earth, a planet on which he was born some two million years later, it was noted that any being other than the Hrarf-Hrarf would find that a terribly lonely position to be in. Book \n Life, the Universe and Everything Radio \n\n Tertiary Phase \n Fit the Thirteenth Tertiary Phase \n Fit the ThirteenthTrivia\nIn The Hitchhiker's Guide to the Galaxy Radio Scripts: Tertiary, Quandary and Quintessential Phases, one of the FX notes during the part of the episode where the Hrarf-Hrarf are mentioned says: “Effects actually recorded in Hrarf-Hrarf birth canal. We leave no effect unauthenticated.”\nCategory:Races and species\nCategory:Flora and fauna"

# %%
base = "https://hitchhikers.fandom.com"

for elem in link_names:
    print(elem)
    try:
        text = text_from_url(elem['href'])
        os.makedirs(os.path.dirname(elem['fn']), exist_ok=True)
        with open(elem['fn'], 'w') as f:
            f.write(text)
    except Exception as e:
        print(e)
# Out:
# {'fn': 'data/dump/hotblack-desiato-s-bodyguard', 'href': 'https://hitchhikers.fandom.com/wiki/Hotblack_Desiato%27s_bodyguard'}
# {'fn': 'data/dump/hrarf-hrarf', 'href': 'https://hitchhikers.fandom.com/wiki/Hrarf-Hrarf'}
# {'fn': 'data/dump/human', 'href': 'https://hitchhikers.fandom.com/wiki/Human'}
# {'fn': 'data/dump/human-beings', 'href': 'https://hitchhikers.fandom.com/wiki/Human_beings'}
# {'fn': 'data/dump/humans', 'href': 'https://hitchhikers.fandom.com/wiki/Humans'}
# {'fn': 'data/dump/humma-kavula', 'href': 'https://hitchhikers.fandom.com/wiki/Humma_Kavula'}
# {'fn': 'data/dump/hurling-frootmig', 'href': 'https://hitchhikers.fandom.com/wiki/Hurling_Frootmig'}
# {'fn': 'data/dump/hyperspace', 'href': 'https://hitchhikers.fandom.com/wiki/Hyperspace'}
# {'fn': 'data/dump/ibiza', 'href': 'https://hitchhikers.fandom.com/wiki/Ibiza'}
# {'fn': 'data/dump/infinidim-enterprises', 'href': 'https://hitchhikers.fandom.com/wiki/InfiniDim_Enterprises'}
# {'fn': 'data/dump/infinidim-enterprises', 'href': 'https://hitchhikers.fandom.com/wiki/Infinidim_Enterprises'}
# {'fn': 'data/dump/infinite-improbability-drive', 'href': 'https://hitchhikers.fandom.com/wiki/Infinite_Improbability_Drive'}
# {'fn': 'data/dump/informational-illusion', 'href': 'https://hitchhikers.fandom.com/wiki/Informational_Illusion'}
# {'fn': 'data/dump/interstellar-hitchhiker', 'href': 'https://hitchhikers.fandom.com/wiki/Interstellar_hitchhiker'}
# {'fn': 'data/dump/ion-drive-delta-boat', 'href': 'https://hitchhikers.fandom.com/wiki/Ion_Drive_Delta_Boat'}
# {'fn': 'data/dump/ion-drive-delta-boat', 'href': 'https://hitchhikers.fandom.com/wiki/Ion_drive_delta_boat'}
# {'fn': 'data/dump/islington', 'href': 'https://hitchhikers.fandom.com/wiki/Islington'}
# {'fn': 'data/dump/jaglan-beta', 'href': 'https://hitchhikers.fandom.com/wiki/Jaglan_Beta'}
# {'fn': 'data/dump/jajazikstak', 'href': 'https://hitchhikers.fandom.com/wiki/Jajazikstak'}
# {'fn': 'data/dump/jane-horrocks', 'href': 'https://hitchhikers.fandom.com/wiki/Jane_Horrocks'}
# {'fn': 'data/dump/janx-spirit', 'href': 'https://hitchhikers.fandom.com/wiki/Janx_Spirit'}
# {'fn': 'data/dump/jatravartid', 'href': 'https://hitchhikers.fandom.com/wiki/Jatravartid'}
# {'fn': 'data/dump/jatravartids', 'href': 'https://hitchhikers.fandom.com/wiki/Jatravartids'}
# {'fn': 'data/dump/jeltz', 'href': 'https://hitchhikers.fandom.com/wiki/Jeltz'}
# {'fn': 'data/dump/jikthroom-beta', 'href': 'https://hitchhikers.fandom.com/wiki/Jikthroom_Beta'}
# {'fn': 'data/dump/jim-broadbent', 'href': 'https://hitchhikers.fandom.com/wiki/Jim_Broadbent'}
# {'fn': 'data/dump/jinjenz', 'href': 'https://hitchhikers.fandom.com/wiki/JinJenz'}
# {'fn': 'data/dump/jin-jenz-reporter', 'href': 'https://hitchhikers.fandom.com/wiki/Jin_Jenz_Reporter'}
# {'fn': 'data/dump/joanna-lumley', 'href': 'https://hitchhikers.fandom.com/wiki/Joanna_Lumley'}
# {'fn': 'data/dump/joggers', 'href': 'https://hitchhikers.fandom.com/wiki/Joggers'}
# {'fn': 'data/dump/john-langdon', 'href': 'https://hitchhikers.fandom.com/wiki/John_Langdon'}
# {'fn': 'data/dump/john-lloyd', 'href': 'https://hitchhikers.fandom.com/wiki/John_Lloyd'}
# {'fn': 'data/dump/john-marsh', 'href': 'https://hitchhikers.fandom.com/wiki/John_Marsh'}
# {'fn': 'data/dump/john-le-mesurier', 'href': 'https://hitchhikers.fandom.com/wiki/John_le_Mesurier'}
# {'fn': 'data/dump/joltrast-3', 'href': 'https://hitchhikers.fandom.com/wiki/Joltrast_3'}
# {'fn': 'data/dump/jonny-brock', 'href': 'https://hitchhikers.fandom.com/wiki/Jonny_Brock'}
# {'fn': 'data/dump/joo-janta-200-super-chromatic-peril-sensitive-sunglasses', 'href': 'https://hitchhikers.fandom.com/wiki/Joo_Janta_200_Super-Chromatic_Peril_Sensitive_Sunglasses'}
# {'fn': 'data/dump/jooplebeery-shrub', 'href': 'https://hitchhikers.fandom.com/wiki/Jooplebeery_Shrub'}
# {'fn': 'data/dump/joopleberry-shrub', 'href': 'https://hitchhikers.fandom.com/wiki/Joopleberry_Shrub'}
# {'fn': 'data/dump/judiciary-pag', 'href': 'https://hitchhikers.fandom.com/wiki/Judiciary_Pag'}
# {'fn': 'data/dump/jynnan-tonnyx', 'href': 'https://hitchhikers.fandom.com/wiki/Jynnan_tonnyx'}
# {'fn': 'data/dump/kakrafoon', 'href': 'https://hitchhikers.fandom.com/wiki/Kakrafoon'}
# {'fn': 'data/dump/kakrafoon-kappa', 'href': 'https://hitchhikers.fandom.com/wiki/Kakrafoon_Kappa'}
# {'fn': 'data/dump/kill-o-zap-gun', 'href': 'https://hitchhikers.fandom.com/wiki/Kill-O-Zap_Gun'}
# {'fn': 'data/dump/kill-o-zap-gun', 'href': 'https://hitchhikers.fandom.com/wiki/Kill-o-Zap_Gun'}
# {'fn': 'data/dump/know-nothing-bozo', 'href': 'https://hitchhikers.fandom.com/wiki/Know-Nothing-Bozo'}
# {'fn': 'data/dump/kria', 'href': 'https://hitchhikers.fandom.com/wiki/Kria'}
# {'fn': 'data/dump/krikkit', 'href': 'https://hitchhikers.fandom.com/wiki/Krikkit'}
# {'fn': 'data/dump/krikkit-one', 'href': 'https://hitchhikers.fandom.com/wiki/Krikkit_One'}
# {'fn': 'data/dump/krikkit-war-robots', 'href': 'https://hitchhikers.fandom.com/wiki/Krikkit_War_Robots'}
# {'fn': 'data/dump/kroompst', 'href': 'https://hitchhikers.fandom.com/wiki/Kroompst'}
# {'fn': 'data/dump/lady-cynthia-fitzmelton', 'href': 'https://hitchhikers.fandom.com/wiki/Lady_Cynthia_Fitzmelton'}
# {'fn': 'data/dump/lajestic-vantrasheel-of-lob', 'href': 'https://hitchhikers.fandom.com/wiki/Lajestic_Vantrasheel_of_Lob'}
# {'fn': 'data/dump/lajestic-vantrashell-of-lob', 'href': 'https://hitchhikers.fandom.com/wiki/Lajestic_Vantrashell_of_Lob'}
# {'fn': 'data/dump/lallafa', 'href': 'https://hitchhikers.fandom.com/wiki/Lallafa'}
# {'fn': 'data/dump/lamuella', 'href': 'https://hitchhikers.fandom.com/wiki/Lamuella'}
# {'fn': 'data/dump/lamuellans', 'href': 'https://hitchhikers.fandom.com/wiki/Lamuellans'}
# {'fn': 'data/dump/lawrence-godfrey', 'href': 'https://hitchhikers.fandom.com/wiki/Lawrence_Godfrey'}
# {'fn': 'data/dump/lazgar-beta', 'href': 'https://hitchhikers.fandom.com/wiki/Lazgar_Beta'}
# {'fn': 'data/dump/lead-balloon', 'href': 'https://hitchhikers.fandom.com/wiki/Lead_Balloon'}
# {'fn': 'data/dump/left-brain', 'href': 'https://hitchhikers.fandom.com/wiki/Left_Brain'}
# {'fn': 'data/dump/leslie-phillips', 'href': 'https://hitchhikers.fandom.com/wiki/Leslie_Phillips'}
# {'fn': 'data/dump/life-the-universe-and-everything', 'href': 'https://hitchhikers.fandom.com/wiki/Life,_the_Universe,_and_Everything'}
# {'fn': 'data/dump/life-the-universe-and-everything', 'href': 'https://hitchhikers.fandom.com/wiki/Life,_the_Universe_and_Everything'}
# {'fn': 'data/dump/lig-lury-jr', 'href': 'https://hitchhikers.fandom.com/wiki/Lig_Lury_Jr'}
# {'fn': 'data/dump/lintilla', 'href': 'https://hitchhikers.fandom.com/wiki/Lintilla'}
# {'fn': 'data/dump/list-of-characters', 'href': 'https://hitchhikers.fandom.com/wiki/List_of_Characters'}
# {'fn': 'data/dump/list-of-races-and-species-in-the-hitchhiker-s-guide-to-the-galaxy', 'href': 'https://hitchhikers.fandom.com/wiki/List_of_races_and_species_in_The_Hitchhiker%27s_Guide_to_the_Galaxy'}
# {'fn': 'data/dump/list-of-technology-in-the-hitchhiker-s-guide-to-the-galaxy', 'href': 'https://hitchhikers.fandom.com/wiki/List_of_technology_in_the_Hitchhiker%27s_Guide_to_the_Galaxy'}
# {'fn': 'data/dump/loki', 'href': 'https://hitchhikers.fandom.com/wiki/Loki'}
# {'fn': 'data/dump/london', 'href': 'https://hitchhikers.fandom.com/wiki/London'}
# {'fn': 'data/dump/loonquawl', 'href': 'https://hitchhikers.fandom.com/wiki/Loonquawl'}
# {'fn': 'data/dump/lord-s-cricket-ground', 'href': 'https://hitchhikers.fandom.com/wiki/Lord%27s_Cricket_Ground'}
# {'fn': 'data/dump/lords-cricket-ground', 'href': 'https://hitchhikers.fandom.com/wiki/Lords_Cricket_Ground'}
# {'fn': 'data/dump/lorelei-king', 'href': 'https://hitchhikers.fandom.com/wiki/Lorelei_King'}
# {'fn': 'data/dump/lunkwill', 'href': 'https://hitchhikers.fandom.com/wiki/Lunkwill'}
# {'fn': 'data/dump/lunkwill-and-fook', 'href': 'https://hitchhikers.fandom.com/wiki/Lunkwill_and_Fook'}
# {'fn': 'data/dump/madagascar', 'href': 'https://hitchhikers.fandom.com/wiki/Madagascar'}
# {'fn': 'data/dump/magrathea', 'href': 'https://hitchhikers.fandom.com/wiki/Magrathea'}
# {'fn': 'data/dump/magrathean', 'href': 'https://hitchhikers.fandom.com/wiki/Magrathean'}
# {'fn': 'data/dump/magrathean-sperm-whale', 'href': 'https://hitchhikers.fandom.com/wiki/Magrathean_sperm_whale'}
# {'fn': 'data/dump/magratheans', 'href': 'https://hitchhikers.fandom.com/wiki/Magratheans'}
# {'fn': 'data/dump/main-page', 'href': 'https://hitchhikers.fandom.com/wiki/Main_Page'}
# {'fn': 'data/dump/majikthise', 'href': 'https://hitchhikers.fandom.com/wiki/Majikthise'}
# {'fn': 'data/dump/mak-wilson', 'href': 'https://hitchhikers.fandom.com/wiki/Mak_Wilson'}
# {'fn': 'data/dump/making-of-the-hitchhiker-s-guide-to-the-galaxy', 'href': 'https://hitchhikers.fandom.com/wiki/Making_of_The_Hitchhiker%27s_Guide_to_the_Galaxy'}
# {'fn': 'data/dump/marc-smith', 'href': 'https://hitchhikers.fandom.com/wiki/Marc_Smith'}
# {'fn': 'data/dump/mark-smith', 'href': 'https://hitchhikers.fandom.com/wiki/Mark_Smith'}
# {'fn': 'data/dump/mark-wing-davey', 'href': 'https://hitchhikers.fandom.com/wiki/Mark_Wing-Davey'}
# {'fn': 'data/dump/martin-benson', 'href': 'https://hitchhikers.fandom.com/wiki/Martin_Benson'}
# {'fn': 'data/dump/martin-freeman', 'href': 'https://hitchhikers.fandom.com/wiki/Martin_Freeman'}
# {'fn': 'data/dump/marvin', 'href': 'https://hitchhikers.fandom.com/wiki/Marvin'}
# {'fn': 'data/dump/marvin-the-paranoid-android', 'href': 'https://hitchhikers.fandom.com/wiki/Marvin_the_Paranoid_Android'}
# {'fn': 'data/dump/mattresses', 'href': 'https://hitchhikers.fandom.com/wiki/Mattresses'}
# {'fn': 'data/dump/max-quordlepleen', 'href': 'https://hitchhikers.fandom.com/wiki/Max_Quordlepleen'}
# {'fn': 'data/dump/maximegalon-institute-of-slowly-and-painfully-working-out-the-surprisingly-obvious', 'href': 'https://hitchhikers.fandom.com/wiki/Maximegalon_Institute_of_Slowly_and_Painfully_Working_Out_the_Surprisingly_Obvious'}
# {'fn': 'data/dump/megabrantis-cluster', 'href': 'https://hitchhikers.fandom.com/wiki/Megabrantis_Cluster'}
# {'fn': 'data/dump/megabrantis-cluster', 'href': 'https://hitchhikers.fandom.com/wiki/Megabrantis_cluster'}
# {'fn': 'data/dump/megadodo-publications', 'href': 'https://hitchhikers.fandom.com/wiki/Megadodo_Publications'}
# {'fn': 'data/dump/mella', 'href': 'https://hitchhikers.fandom.com/wiki/Mella'}
# {'fn': 'data/dump/mice', 'href': 'https://hitchhikers.fandom.com/wiki/Mice'}
# {'fn': 'data/dump/michael-cule', 'href': 'https://hitchhikers.fandom.com/wiki/Michael_Cule'}
# {'fn': 'data/dump/michael-fenton-stevens', 'href': 'https://hitchhikers.fandom.com/wiki/Michael_Fenton_Stevens'}
# {'fn': 'data/dump/mid-galactic-arts-nobbling-council', 'href': 'https://hitchhikers.fandom.com/wiki/Mid-Galactic_Arts_Nobbling_Council'}
# {'fn': 'data/dump/milky-way', 'href': 'https://hitchhikers.fandom.com/wiki/Milky_Way'}
# {'fn': 'data/dump/milliard-gargantubrain', 'href': 'https://hitchhikers.fandom.com/wiki/Milliard_Gargantubrain'}
# {'fn': 'data/dump/milliways', 'href': 'https://hitchhikers.fandom.com/wiki/Milliways'}
# {'fn': 'data/dump/miriam-margolyes', 'href': 'https://hitchhikers.fandom.com/wiki/Miriam_Margolyes'}
# {'fn': 'data/dump/mitch-benn', 'href': 'https://hitchhikers.fandom.com/wiki/Mitch_Benn'}
# {'fn': 'data/dump/mostly-harmless', 'href': 'https://hitchhikers.fandom.com/wiki/Mostly_Harmless'}
# {'fn': 'data/dump/mouse', 'href': 'https://hitchhikers.fandom.com/wiki/Mouse'}
# {'fn': 'data/dump/mr-prosser', 'href': 'https://hitchhikers.fandom.com/wiki/Mr._Prosser'}
# {'fn': 'data/dump/mr-prosser', 'href': 'https://hitchhikers.fandom.com/wiki/Mr_Prosser'}
# {'fn': 'data/dump/multicorticoid-perspecutron-titan-muller', 'href': 'https://hitchhikers.fandom.com/wiki/Multicorticoid_Perspecutron_Titan_Muller'}
# {'fn': 'data/dump/multicorticoid-perspicutron-titan-muller', 'href': 'https://hitchhikers.fandom.com/wiki/Multicorticoid_Perspicutron_Titan_Muller'}
# {'fn': 'data/dump/murray-bost-henson', 'href': 'https://hitchhikers.fandom.com/wiki/Murray_Bost_Henson'}
# {'fn': 'data/dump/my-favourite-bathtime-gurgles', 'href': 'https://hitchhikers.fandom.com/wiki/My_Favourite_Bathtime_Gurgles'}
# {'fn': 'data/dump/nanites', 'href': 'https://hitchhikers.fandom.com/wiki/Nanites'}
# {'fn': 'data/dump/nano', 'href': 'https://hitchhikers.fandom.com/wiki/Nano'}
# {'fn': 'data/dump/nanoism', 'href': 'https://hitchhikers.fandom.com/wiki/Nanoism'}
# {'fn': 'data/dump/neanderthal', 'href': 'https://hitchhikers.fandom.com/wiki/Neanderthal'}
# {'fn': 'data/dump/nephologia', 'href': 'https://hitchhikers.fandom.com/wiki/Nephologia'}
# {'fn': 'data/dump/neptune', 'href': 'https://hitchhikers.fandom.com/wiki/Neptune'}
# {'fn': 'data/dump/ningi', 'href': 'https://hitchhikers.fandom.com/wiki/Ningi'}
# {'fn': 'data/dump/noir', 'href': 'https://hitchhikers.fandom.com/wiki/Noir'}
# {'fn': 'data/dump/north-west-ripple', 'href': 'https://hitchhikers.fandom.com/wiki/North_West_Ripple'}
# {'fn': 'data/dump/norway', 'href': 'https://hitchhikers.fandom.com/wiki/Norway'}
# {'fn': 'data/dump/nowwhat', 'href': 'https://hitchhikers.fandom.com/wiki/NowWhat'}
# {'fn': 'data/dump/number-one', 'href': 'https://hitchhikers.fandom.com/wiki/Number_One'}
# {'fn': 'data/dump/number-two', 'href': 'https://hitchhikers.fandom.com/wiki/Number_Two'}
# {'fn': 'data/dump/nutri-matic-drink-synthesizer', 'href': 'https://hitchhikers.fandom.com/wiki/Nutri-Matic_Drink_Synthesizer'}
# {'fn': 'data/dump/nutrimatic-appliance', 'href': 'https://hitchhikers.fandom.com/wiki/Nutrimatic_Appliance'}
# {'fn': 'data/dump/nutrimatic-drinks-dispenser', 'href': 'https://hitchhikers.fandom.com/wiki/Nutrimatic_Drinks_Dispenser'}
# {'fn': 'data/dump/obsessed', 'href': 'https://hitchhikers.fandom.com/wiki/Obsessed%3F'}
# {'fn': 'data/dump/ode-to-a-small-lump-of-green-putty-i-found-in-my-armpit-one-midsummer-morning', 'href': 'https://hitchhikers.fandom.com/wiki/Ode_to_a_Small_Lump_of_Green_Putty_I_Found_in_My_Armpit_One_Midsummer_Morning'}
# {'fn': 'data/dump/odin', 'href': 'https://hitchhikers.fandom.com/wiki/Odin'}
# {'fn': 'data/dump/oglaroon', 'href': 'https://hitchhikers.fandom.com/wiki/Oglaroon'}
# {'fn': 'data/dump/ohwell', 'href': 'https://hitchhikers.fandom.com/wiki/OhWell'}
# {'fn': 'data/dump/old-man-on-the-pole', 'href': 'https://hitchhikers.fandom.com/wiki/Old_Man_on_the_Pole'}
# {'fn': 'data/dump/old-pink-dog-bar', 'href': 'https://hitchhikers.fandom.com/wiki/Old_Pink_Dog_Bar'}
# {'fn': 'data/dump/old-thrashbarg', 'href': 'https://hitchhikers.fandom.com/wiki/Old_Thrashbarg'}
# {'fn': 'data/dump/old-woman-in-the-cave', 'href': 'https://hitchhikers.fandom.com/wiki/Old_Woman_in_the_Cave'}
# {'fn': 'data/dump/oolon-colluphid', 'href': 'https://hitchhikers.fandom.com/wiki/Oolon_Colluphid'}
# {'fn': 'data/dump/orion-beta', 'href': 'https://hitchhikers.fandom.com/wiki/Orion_Beta'}
# {'fn': 'data/dump/outer-eastern-rim', 'href': 'https://hitchhikers.fandom.com/wiki/Outer_Eastern_Rim'}
# {'fn': 'data/dump/outer-eastern-rim', 'href': 'https://hitchhikers.fandom.com/wiki/Outer_Eastern_Rim.'}
# {'fn': 'data/dump/paddy-kingsland', 'href': 'https://hitchhikers.fandom.com/wiki/Paddy_Kingsland'}
# {'fn': 'data/dump/pan-galactic-gargle-blaster', 'href': 'https://hitchhikers.fandom.com/wiki/Pan_Galactic_Gargle_Blaster'}
# {'fn': 'data/dump/pasta-fasta', 'href': 'https://hitchhikers.fandom.com/wiki/Pasta_Fasta'}
# {'fn': 'data/dump/paul-neil-milne-johnstone', 'href': 'https://hitchhikers.fandom.com/wiki/Paul_Neil_Milne_Johnstone'}
# {'fn': 'data/dump/paul-wix-wickens', 'href': 'https://hitchhikers.fandom.com/wiki/Paul_Wix_Wickens'}
# {'fn': 'data/dump/paula-nancy-millstone-jennings', 'href': 'https://hitchhikers.fandom.com/wiki/Paula_Nancy_Millstone_Jennings'}
# {'fn': 'data/dump/peanut', 'href': 'https://hitchhikers.fandom.com/wiki/Peanut'}
# {'fn': 'data/dump/peanuts', 'href': 'https://hitchhikers.fandom.com/wiki/Peanuts'}
# {'fn': 'data/dump/perfectly-normal-beast', 'href': 'https://hitchhikers.fandom.com/wiki/Perfectly_Normal_Beast'}
# {'fn': 'data/dump/perfectly-normal-beasts', 'href': 'https://hitchhikers.fandom.com/wiki/Perfectly_Normal_Beasts'}
# {'fn': 'data/dump/perspex-pillar-of-science-and-reason', 'href': 'https://hitchhikers.fandom.com/wiki/Perspex_Pillar_of_Science_and_Reason'}
# {'fn': 'data/dump/peter-davison', 'href': 'https://hitchhikers.fandom.com/wiki/Peter_Davison'}
# {'fn': 'data/dump/peter-jones', 'href': 'https://hitchhikers.fandom.com/wiki/Peter_Jones'}
# {'fn': 'data/dump/philip-pope', 'href': 'https://hitchhikers.fandom.com/wiki/Philip_Pope'}
# {'fn': 'data/dump/phouchg', 'href': 'https://hitchhikers.fandom.com/wiki/Phouchg'}
# {'fn': 'data/dump/phouchg-and-loonquawl', 'href': 'https://hitchhikers.fandom.com/wiki/Phouchg_and_Loonquawl'}
# {'fn': 'data/dump/pikka-birds', 'href': 'https://hitchhikers.fandom.com/wiki/Pikka_Birds'}
# {'fn': 'data/dump/pizpot-gargravarr', 'href': 'https://hitchhikers.fandom.com/wiki/Pizpot_Gargravarr'}
# {'fn': 'data/dump/playbeing-magazine', 'href': 'https://hitchhikers.fandom.com/wiki/Playbeing_magazine'}
# {'fn': 'data/dump/pleiades-system', 'href': 'https://hitchhikers.fandom.com/wiki/Pleiades_system'}
# {'fn': 'data/dump/plural-zone', 'href': 'https://hitchhikers.fandom.com/wiki/Plural_zone'}
# {'fn': 'data/dump/pluto', 'href': 'https://hitchhikers.fandom.com/wiki/Pluto'}
# {'fn': 'data/dump/poghril', 'href': 'https://hitchhikers.fandom.com/wiki/Poghril'}
# {'fn': 'data/dump/point-of-view-gun', 'href': 'https://hitchhikers.fandom.com/wiki/Point_of_View_gun'}
# {'fn': 'data/dump/polyphill-ah', 'href': 'https://hitchhikers.fandom.com/wiki/Polyphill-Ah'}
# {'fn': 'data/dump/pondermatic', 'href': 'https://hitchhikers.fandom.com/wiki/Pondermatic'}
# {'fn': 'data/dump/poodoo', 'href': 'https://hitchhikers.fandom.com/wiki/Poodoo'}
# {'fn': 'data/dump/port-sesefron', 'href': 'https://hitchhikers.fandom.com/wiki/Port_Sesefron'}
# {'fn': 'data/dump/power-of-art', 'href': 'https://hitchhikers.fandom.com/wiki/Power_of_Art'}
# {'fn': 'data/dump/prak', 'href': 'https://hitchhikers.fandom.com/wiki/Prak'}
# {'fn': 'data/dump/prefect', 'href': 'https://hitchhikers.fandom.com/wiki/Prefect'}
# {'fn': 'data/dump/preliumtarn', 'href': 'https://hitchhikers.fandom.com/wiki/Preliumtarn'}
# {'fn': 'data/dump/president-of-the-galaxy', 'href': 'https://hitchhikers.fandom.com/wiki/President_of_the_Galaxy'}
# {'fn': 'data/dump/president-of-the-imperial-galactic-government', 'href': 'https://hitchhikers.fandom.com/wiki/President_of_the_Imperial_Galactic_Government'}
# {'fn': 'data/dump/primary-phase', 'href': 'https://hitchhikers.fandom.com/wiki/Primary_Phase'}
# {'fn': 'data/dump/prostetnic-vogon-jeltz', 'href': 'https://hitchhikers.fandom.com/wiki/Prostetnic_Vogon_Jeltz'}
# {'fn': 'data/dump/prostetnic-vogon-kwaltz', 'href': 'https://hitchhikers.fandom.com/wiki/Prostetnic_Vogon_Kwaltz'}
# {'fn': 'data/dump/pseudo-fractures', 'href': 'https://hitchhikers.fandom.com/wiki/Pseudo-fractures'}
# {'fn': 'data/dump/qq7-active-j-gamma', 'href': 'https://hitchhikers.fandom.com/wiki/QQ7_Active_J_Gamma'}
# {'fn': 'data/dump/quest', 'href': 'https://hitchhikers.fandom.com/wiki/QUEST'}
# {'fn': 'data/dump/quandary-phase', 'href': 'https://hitchhikers.fandom.com/wiki/Quandary_Phase'}
# {'fn': 'data/dump/questular-rontok', 'href': 'https://hitchhikers.fandom.com/wiki/Questular_Rontok'}
# {'fn': 'data/dump/quintessential-phase', 'href': 'https://hitchhikers.fandom.com/wiki/Quintessential_Phase'}
# {'fn': 'data/dump/rw6', 'href': 'https://hitchhikers.fandom.com/wiki/RW6'}
# {'fn': 'data/dump/random-dent', 'href': 'https://hitchhikers.fandom.com/wiki/Random_Dent'}
# {'fn': 'data/dump/ratchet-screwdriver-fruit', 'href': 'https://hitchhikers.fandom.com/wiki/Ratchet_screwdriver_fruit'}
# {'fn': 'data/dump/ravenous-bugblatter-beast-of-traal', 'href': 'https://hitchhikers.fandom.com/wiki/Ravenous_Bugblatter_Beast_of_Traal'}
# {'fn': 'data/dump/reg-nullify', 'href': 'https://hitchhikers.fandom.com/wiki/Reg_Nullify'}
# {'fn': 'data/dump/reg-nullify-in-concert', 'href': 'https://hitchhikers.fandom.com/wiki/Reg_Nullify_in_Concert'}
# {'fn': 'data/dump/reverse-temporal-engineering', 'href': 'https://hitchhikers.fandom.com/wiki/Reverse_Temporal_Engineering'}
# {'fn': 'data/dump/richard-griffiths', 'href': 'https://hitchhikers.fandom.com/wiki/Richard_Griffiths'}
# {'fn': 'data/dump/richard-vernon', 'href': 'https://hitchhikers.fandom.com/wiki/Richard_Vernon'}
# {'fn': 'data/dump/rickmansworth', 'href': 'https://hitchhikers.fandom.com/wiki/Rickmansworth'}
# {'fn': 'data/dump/river-moth', 'href': 'https://hitchhikers.fandom.com/wiki/River_Moth'}
# {'fn': 'data/dump/rob-mckenna', 'href': 'https://hitchhikers.fandom.com/wiki/Rob_McKenna'}
# {'fn': 'data/dump/robot', 'href': 'https://hitchhikers.fandom.com/wiki/Robot'}
# {'fn': 'data/dump/roger-gregg', 'href': 'https://hitchhikers.fandom.com/wiki/Roger_Gregg'}
# {'fn': 'data/dump/roosta', 'href': 'https://hitchhikers.fandom.com/wiki/Roosta'}
# {'fn': 'data/dump/rory-award', 'href': 'https://hitchhikers.fandom.com/wiki/Rory_Award'}
# {'fn': 'data/dump/rory-award-winner', 'href': 'https://hitchhikers.fandom.com/wiki/Rory_Award_Winner'}
# {'fn': 'data/dump/roy-hudd', 'href': 'https://hitchhikers.fandom.com/wiki/Roy_Hudd'}
# {'fn': 'data/dump/rubber-ducks', 'href': 'https://hitchhikers.fandom.com/wiki/Rubber_Ducks'}
# {'fn': 'data/dump/rubber-duck', 'href': 'https://hitchhikers.fandom.com/wiki/Rubber_duck'}
# {'fn': 'data/dump/rula-lenska', 'href': 'https://hitchhikers.fandom.com/wiki/Rula_Lenska'}
# {'fn': 'data/dump/ruler-of-the-universe', 'href': 'https://hitchhikers.fandom.com/wiki/Ruler_of_the_Universe'}
# {'fn': 'data/dump/rupert', 'href': 'https://hitchhikers.fandom.com/wiki/Rupert'}
# {'fn': 'data/dump/russell', 'href': 'https://hitchhikers.fandom.com/wiki/Russell'}
# {'fn': 'data/dump/sam-beart', 'href': 'https://hitchhikers.fandom.com/wiki/Sam_B%C3%A9art'}
# {'fn': 'data/dump/sandbox', 'href': 'https://hitchhikers.fandom.com/wiki/Sandbox'}
# {'fn': 'data/dump/sandra-dickinson', 'href': 'https://hitchhikers.fandom.com/wiki/Sandra_Dickinson'}
# {'fn': 'data/dump/santraginus', 'href': 'https://hitchhikers.fandom.com/wiki/Santraginus'}
# {'fn': 'data/dump/santraginus-v', 'href': 'https://hitchhikers.fandom.com/wiki/Santraginus_V'}
# {'fn': 'data/dump/saquo-pilia-hensha', 'href': 'https://hitchhikers.fandom.com/wiki/Saquo-Pilia_Hensha'}
# {'fn': 'data/dump/sarkopsi', 'href': 'https://hitchhikers.fandom.com/wiki/Sarkopsi'}
# {'fn': 'data/dump/sass', 'href': 'https://hitchhikers.fandom.com/wiki/Sass'}
# {'fn': 'data/dump/scintillating-jeweled-scuttling-crab', 'href': 'https://hitchhikers.fandom.com/wiki/Scintillating_Jeweled_Scuttling_Crab'}
# {'fn': 'data/dump/scintillating-jewelled-scuttling-crab', 'href': 'https://hitchhikers.fandom.com/wiki/Scintillating_Jewelled_Scuttling_Crab'}
# {'fn': 'data/dump/scintillating-jewelled-scuttling-crabs', 'href': 'https://hitchhikers.fandom.com/wiki/Scintillating_Jewelled_Scuttling_Crabs'}
# {'fn': 'data/dump/scrabble', 'href': 'https://hitchhikers.fandom.com/wiki/Scrabble'}
# {'fn': 'data/dump/secondary-phase', 'href': 'https://hitchhikers.fandom.com/wiki/Secondary_Phase'}
# {'fn': 'data/dump/sector-xxxz5qzx', 'href': 'https://hitchhikers.fandom.com/wiki/Sector_XXXZ5QZX'}
# {'fn': 'data/dump/sector-zz9-plural-z-alpha', 'href': 'https://hitchhikers.fandom.com/wiki/Sector_ZZ9_Plural_Z_Alpha'}
# {'fn': 'data/dump/sens-o-tape', 'href': 'https://hitchhikers.fandom.com/wiki/Sens-O-Tape'}
# {'fn': 'data/dump/sesefras-magna', 'href': 'https://hitchhikers.fandom.com/wiki/Sesefras_Magna'}
# {'fn': 'data/dump/seventh-galaxy-of-light-and-ingenuity', 'href': 'https://hitchhikers.fandom.com/wiki/Seventh_Galaxy_of_Light_and_Ingenuity'}
# {'fn': 'data/dump/shaltanac', 'href': 'https://hitchhikers.fandom.com/wiki/Shaltanac'}
# {'fn': 'data/dump/shaltanacs', 'href': 'https://hitchhikers.fandom.com/wiki/Shaltanacs'}
# {'fn': 'data/dump/share-and-enjoy', 'href': 'https://hitchhikers.fandom.com/wiki/Share_and_Enjoy'}
# {'fn': 'data/dump/shoe-event-horizon', 'href': 'https://hitchhikers.fandom.com/wiki/Shoe_Event_Horizon'}
# {'fn': 'data/dump/shooty', 'href': 'https://hitchhikers.fandom.com/wiki/Shooty'}
# {'fn': 'data/dump/shooty-and-bang-bang', 'href': 'https://hitchhikers.fandom.com/wiki/Shooty_and_Bang_Bang'}
# {'fn': 'data/dump/silastic-armorfiends', 'href': 'https://hitchhikers.fandom.com/wiki/Silastic_Armorfiends'}
# {'fn': 'data/dump/silver-bail-of-peace', 'href': 'https://hitchhikers.fandom.com/wiki/Silver_Bail_of_Peace'}
# {'fn': 'data/dump/silver-tongued-devils', 'href': 'https://hitchhikers.fandom.com/wiki/Silver_Tongued_Devils'}
# {'fn': 'data/dump/silver-toungued-devils', 'href': 'https://hitchhikers.fandom.com/wiki/Silver_Toungued_Devils'}
# {'fn': 'data/dump/simon-brett', 'href': 'https://hitchhikers.fandom.com/wiki/Simon_Brett'}
# {'fn': 'data/dump/simon-jones', 'href': 'https://hitchhikers.fandom.com/wiki/Simon_Jones'}
# {'fn': 'data/dump/sir-isaac-newton', 'href': 'https://hitchhikers.fandom.com/wiki/Sir_Isaac_Newton'}
# {'fn': 'data/dump/sirius-cybernetcs-corperation-complaints-department', 'href': 'https://hitchhikers.fandom.com/wiki/Sirius_Cybernetcs_Corperation_Complaints_Department'}
# {'fn': 'data/dump/sirius-cybernetics-corporation', 'href': 'https://hitchhikers.fandom.com/wiki/Sirius_Cybernetics_Corporation'}
# {'fn': 'data/dump/sirius-cybernetics-corporation-complaints-department', 'href': 'https://hitchhikers.fandom.com/wiki/Sirius_Cybernetics_Corporation_Complaints_Department'}
# {'fn': 'data/dump/sirius-tau', 'href': 'https://hitchhikers.fandom.com/wiki/Sirius_Tau'}
# {'fn': 'data/dump/skaoi', 'href': 'https://hitchhikers.fandom.com/wiki/Skaoi'}
# {'fn': 'data/dump/slartibartfast', 'href': 'https://hitchhikers.fandom.com/wiki/Slartibartfast'}
# {'fn': 'data/dump/slim-s-throat-emporium', 'href': 'https://hitchhikers.fandom.com/wiki/Slim%27s_Throat_Emporium'}
# {'fn': 'data/dump/slo-time-envelope', 'href': 'https://hitchhikers.fandom.com/wiki/Slo-Time_Envelope'}
# {'fn': 'data/dump/so-long-and-thanks-for-all-the-fish', 'href': 'https://hitchhikers.fandom.com/wiki/So_Long,_and_Thanks_For_All_the_Fish'}
# {'fn': 'data/dump/so-long-and-thanks-for-all-the-fish-song', 'href': 'https://hitchhikers.fandom.com/wiki/So_Long,_and_Thanks_For_All_the_Fish_(song)'}
# {'fn': 'data/dump/so-long-and-thanks-for-all-the-fish', 'href': 'https://hitchhikers.fandom.com/wiki/So_Long,_and_Thanks_for_All_the_Fish'}
# {'fn': 'data/dump/sofa', 'href': 'https://hitchhikers.fandom.com/wiki/Sofa'}
# {'fn': 'data/dump/sol', 'href': 'https://hitchhikers.fandom.com/wiki/Sol'}
# {'fn': 'data/dump/some-more-of-god-s-greatest-mistakes', 'href': 'https://hitchhikers.fandom.com/wiki/Some_More_of_God%27s_Greatest_Mistakes'}
# {'fn': 'data/dump/somebody-else-s-problem-field', 'href': 'https://hitchhikers.fandom.com/wiki/Somebody_Else%27s_Problem_Field'}
# {'fn': 'data/dump/somebody-else-s-problem-field', 'href': 'https://hitchhikers.fandom.com/wiki/Somebody_Else%27s_Problem_field'}
# {'fn': 'data/dump/songs-of-the-long-land', 'href': 'https://hitchhikers.fandom.com/wiki/Songs_of_the_Long_Land'}
# {'fn': 'data/dump/sonny-mehta', 'href': 'https://hitchhikers.fandom.com/wiki/Sonny_Mehta'}
# {'fn': 'data/dump/southend-on-sea', 'href': 'https://hitchhikers.fandom.com/wiki/Southend-on-Sea'}
# {'fn': 'data/dump/space', 'href': 'https://hitchhikers.fandom.com/wiki/Space'}
# {'fn': 'data/dump/spacecraft', 'href': 'https://hitchhikers.fandom.com/wiki/Spacecraft'}
# {'fn': 'data/dump/speaking-clock', 'href': 'https://hitchhikers.fandom.com/wiki/Speaking_Clock'}
# {'fn': 'data/dump/speaking-clock', 'href': 'https://hitchhikers.fandom.com/wiki/Speaking_clock'}
# {'fn': 'data/dump/sqornshellous', 'href': 'https://hitchhikers.fandom.com/wiki/Sqornshellous'}
# {'fn': 'data/dump/sqornshellous-delta', 'href': 'https://hitchhikers.fandom.com/wiki/Sqornshellous_Delta'}
# {'fn': 'data/dump/sqornshellous-swamptalk', 'href': 'https://hitchhikers.fandom.com/wiki/Sqornshellous_Swamptalk'}
# {'fn': 'data/dump/sqornshellous-zeta', 'href': 'https://hitchhikers.fandom.com/wiki/Sqornshellous_Zeta'}
# {'fn': 'data/dump/squornshellous-swamptalk', 'href': 'https://hitchhikers.fandom.com/wiki/Squornshellous_Swamptalk'}
# {'fn': 'data/dump/squornshellous-zeta', 'href': 'https://hitchhikers.fandom.com/wiki/Squornshellous_Zeta'}
# {'fn': 'data/dump/st-antwelm', 'href': 'https://hitchhikers.fandom.com/wiki/St._Antwelm'}
# {'fn': 'data/dump/stagyar-zil-doggo', 'href': 'https://hitchhikers.fandom.com/wiki/Stagyar-zil-Doggo'}
# {'fn': 'data/dump/star-trolley', 'href': 'https://hitchhikers.fandom.com/wiki/Star_trolley'}
# {'fn': 'data/dump/starbix', 'href': 'https://hitchhikers.fandom.com/wiki/Starbix'}
# {'fn': 'data/dump/starship-titanic', 'href': 'https://hitchhikers.fandom.com/wiki/Starship_Titanic'}
# {'fn': 'data/dump/starship-titanic-video-game', 'href': 'https://hitchhikers.fandom.com/wiki/Starship_Titanic_(video_game)'}
# {'fn': 'data/dump/stavro-mueller', 'href': 'https://hitchhikers.fandom.com/wiki/Stavro_Mueller'}
# {'fn': 'data/dump/stavro-mueller-beta', 'href': 'https://hitchhikers.fandom.com/wiki/Stavro_Mueller_Beta'}
# {'fn': 'data/dump/stavromula-beta', 'href': 'https://hitchhikers.fandom.com/wiki/Stavromula_Beta'}
# {'fn': 'data/dump/steel-pillar-of-strength-and-power', 'href': 'https://hitchhikers.fandom.com/wiki/Steel_Pillar_of_Strength_and_Power'}
# {'fn': 'data/dump/stephen-fry', 'href': 'https://hitchhikers.fandom.com/wiki/Stephen_Fry'}
# {'fn': 'data/dump/stephen-moore', 'href': 'https://hitchhikers.fandom.com/wiki/Stephen_Moore'}
# {'fn': 'data/dump/steve-trainer', 'href': 'https://hitchhikers.fandom.com/wiki/Steve_Trainer'}
# {'fn': 'data/dump/strag', 'href': 'https://hitchhikers.fandom.com/wiki/Strag'}
# {'fn': 'data/dump/strangulous-stilettians', 'href': 'https://hitchhikers.fandom.com/wiki/Strangulous_Stilettians'}
# {'fn': 'data/dump/strinder', 'href': 'https://hitchhikers.fandom.com/wiki/Strinder'}
# {'fn': 'data/dump/striterax', 'href': 'https://hitchhikers.fandom.com/wiki/Striterax'}
# {'fn': 'data/dump/stug', 'href': 'https://hitchhikers.fandom.com/wiki/Stug'}
# {'fn': 'data/dump/sub-etha', 'href': 'https://hitchhikers.fandom.com/wiki/Sub-Etha'}
# {'fn': 'data/dump/sub-etha-sens-o-matic', 'href': 'https://hitchhikers.fandom.com/wiki/Sub-Etha_Sens-O-Matic'}
# {'fn': 'data/dump/sus', 'href': 'https://hitchhikers.fandom.com/wiki/Sus'}
# {'fn': 'data/dump/susan-sheridan', 'href': 'https://hitchhikers.fandom.com/wiki/Susan_Sheridan'}
# {'fn': 'data/dump/tanngrisnir', 'href': 'https://hitchhikers.fandom.com/wiki/Tanngrisnir'}
# {'fn': 'data/dump/tapestry-of-arium', 'href': 'https://hitchhikers.fandom.com/wiki/Tapestry_of_Arium'}
# {'fn': 'data/dump/taunton', 'href': 'https://hitchhikers.fandom.com/wiki/Taunton'}
# {'fn': 'data/dump/tea', 'href': 'https://hitchhikers.fandom.com/wiki/Tea'}
# {'fn': 'data/dump/teaser', 'href': 'https://hitchhikers.fandom.com/wiki/Teaser'}
# {'fn': 'data/dump/technology-in-the-hitchhiker-s-guide-to-the-galaxy', 'href': 'https://hitchhikers.fandom.com/wiki/Technology_in_the_Hitchhiker%27s_Guide_to_the_Galaxy'}
# {'fn': 'data/dump/tertiary-phase', 'href': 'https://hitchhikers.fandom.com/wiki/Tertiary_Phase'}
# {'fn': 'data/dump/the-allitnils', 'href': 'https://hitchhikers.fandom.com/wiki/The_Allitnils'}
# {'fn': 'data/dump/the-big-bang-burger-bar', 'href': 'https://hitchhikers.fandom.com/wiki/The_Big_Bang_Burger_Bar'}
# {'fn': 'data/dump/the-book', 'href': 'https://hitchhikers.fandom.com/wiki/The_Book'}
# {'fn': 'data/dump/the-celestial-home-care-omnibus', 'href': 'https://hitchhikers.fandom.com/wiki/The_Celestial_Home_Care_Omnibus'}
# {'fn': 'data/dump/the-cheese', 'href': 'https://hitchhikers.fandom.com/wiki/The_Cheese'}
# {'fn': 'data/dump/the-cosmic-cutie', 'href': 'https://hitchhikers.fandom.com/wiki/The_Cosmic_Cutie'}
# {'fn': 'data/dump/the-creation-of-the-universe', 'href': 'https://hitchhikers.fandom.com/wiki/The_Creation_of_the_Universe'}
# {'fn': 'data/dump/the-deeper-meaning-of-liff', 'href': 'https://hitchhikers.fandom.com/wiki/The_Deeper_Meaning_of_Liff'}
# {'fn': 'data/dump/the-domain-of-the-king', 'href': 'https://hitchhikers.fandom.com/wiki/The_Domain_of_The_King'}
# {'fn': 'data/dump/the-gold-bail-of-prosperity', 'href': 'https://hitchhikers.fandom.com/wiki/The_Gold_Bail_of_Prosperity'}
# {'fn': 'data/dump/the-great-collapsing-hrung-disaster', 'href': 'https://hitchhikers.fandom.com/wiki/The_Great_Collapsing_Hrung_Disaster'}
# {'fn': 'data/dump/the-great-prophet-zarquon', 'href': 'https://hitchhikers.fandom.com/wiki/The_Great_Prophet_Zarquon'}
# {'fn': 'data/dump/the-guide', 'href': 'https://hitchhikers.fandom.com/wiki/The_Guide'}
# {'fn': 'data/dump/the-guide-mark-ii', 'href': 'https://hitchhikers.fandom.com/wiki/The_Guide_Mark_II'}
# {'fn': 'data/dump/the-hitch-hiker-s-guide-to-the-galaxy-tv-theme-music', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitch-Hiker%27s_Guide_to_the_Galaxy_TV_Theme_Music'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-the-original-radio-scripts', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy:_The_Original_Radio_Scripts'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-hulu', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(Hulu)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-lp', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(LP)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-tv-series', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(TV_series)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-book', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(book)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-comic-books', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(comic_books)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-computer-game', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(computer_game)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-film', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(film)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-radio-series', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(radio_series)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-trading-cards', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(trading_cards)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-travel-guide', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(travel_guide)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-video-game', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(video_game)'}
# {'fn': 'data/dump/the-hitchhiker-s-guide-to-the-galaxy-radio-scripts-tertiary-quandary-and-quintessential-phases', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_Radio_Scripts:_Tertiary,_Quandary_and_Quintessential_Phases'}
# {'fn': 'data/dump/the-hitchhikers-guide-to-the-galaxy', 'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhikers_Guide_to_the_Galaxy'}
# {'fn': 'data/dump/the-horse-and-groom', 'href': 'https://hitchhikers.fandom.com/wiki/The_Horse_and_Groom'}
# {'fn': 'data/dump/the-long-dark-tea-time-of-the-soul', 'href': 'https://hitchhikers.fandom.com/wiki/The_Long_Dark_Tea-Time_of_the_Soul'}
# {'fn': 'data/dump/the-longest-cocktail-party', 'href': 'https://hitchhikers.fandom.com/wiki/The_Longest_Cocktail_Party'}
# {'fn': 'data/dump/the-lord', 'href': 'https://hitchhikers.fandom.com/wiki/The_Lord'}
# {'fn': 'data/dump/the-meaning-of-liff', 'href': 'https://hitchhikers.fandom.com/wiki/The_Meaning_of_Liff'}
# {'fn': 'data/dump/the-outside-of-the-asylum', 'href': 'https://hitchhikers.fandom.com/wiki/The_Outside_of_the_Asylum'}
# {'fn': 'data/dump/the-perspex-pillar-of-science-and-reason', 'href': 'https://hitchhikers.fandom.com/wiki/The_Perspex_Pillar_of_Science_and_Reason'}
# {'fn': 'data/dump/the-pitchforker-s-pride-is-a-fallacy', 'href': 'https://hitchhikers.fandom.com/wiki/The_Pitchforker%27s_Pride_is_a_Fallacy'}
# {'fn': 'data/dump/the-pleiades-system', 'href': 'https://hitchhikers.fandom.com/wiki/The_Pleiades_system'}
# {'fn': 'data/dump/the-red-lion', 'href': 'https://hitchhikers.fandom.com/wiki/The_Red_Lion'}
# {'fn': 'data/dump/the-restaurant-at-the-end-of-the-universe', 'href': 'https://hitchhikers.fandom.com/wiki/The_Restaurant_at_the_End_of_the_Universe'}
# {'fn': 'data/dump/the-restaurant-at-the-end-of-the-universe-lp', 'href': 'https://hitchhikers.fandom.com/wiki/The_Restaurant_at_the_End_of_the_Universe_(LP)'}
# {'fn': 'data/dump/the-ruler-of-the-universe', 'href': 'https://hitchhikers.fandom.com/wiki/The_Ruler_of_the_Universe'}

# %% [markdown]
# ## Traversing the main page
#
# Visits the links from the main page with a

# %%
url = "https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(book)"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
content_el = soup.find(id = "mw-content-text")

# %%
url = "https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(book)"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
content_el = soup.find(id = "mw-content-text")

# %%
base = "https://hitchhikers.fandom.com"

clean_last_seen_header = ""
scrape_list = []

# Visits everything and fills it in
def clean_visit_node(node):
    global last_seen_header;
    global start_offset_reached;
    
    if node.name in header_tags:
        last_seen_header = node.text
    
    # if the last seen header is something that we don't want remove it
    if node.name == "a" and len(node.text.strip()) > 0 and "#" not in node.get('href'):
        fn = slugify(last_seen_header) + os.sep + slugify(node.text) + ".txt"
        href = node.get('href')
        
        scrape_list.append({"fn" : "data" + os.sep + fn, "href": base + href})

    for child in node.children:
        if child.name is not None:
            clean_visit_node(child)

clean_visit_node(content_el)

# %%
for elem in scrape_list:
    text = text_from_url(elem['href'])
    os.makedirs(os.path.dirname(elem['fn']), exist_ok=True)
    with open(elem['fn'], 'w') as f:
        f.write(text)

# %%
text_from_url("https://hitchhikers.fandom.com/wiki/Earth
# Out:
# 'Earth was a giant supercomputer designed to find the Ultimate Question of Life, the Universe and Everything. Designed by Deep Thought and built by the Magratheans, it was commonly mistaken for a planet, especially by the ape descendants who lived on it. It was situated far out in the uncharted backwaters of the unfashionable end of the Western Spiral Arm of the Galaxy.\n\nUnfortunately, the Earth was destroyed by the Vogons five minutes before the program was to be completed. The Vogons were sent by the psychiatrist Gag Halfrunt, who thought his profession would cease if the Question were known. Later on, the Earth reappeared but all forms of the Earth were later demolished.\n\nThe only two humans to survive the Earth\'s destruction were Arthur Dent and Trillian.Elvis was revealed to be singing at The Domain of The King, though he may not have been human to begin with.Lifeforms\nEarth was mainly populated by "ape-descended life forms" or\xa0Humans, which number around 6.5 billion at the time of the earth\'s destruction. The earth is also inhabited by a series of flora and fauna, including the mice and dolphins, the most and second most intelligent species on the supercomputer respectively, with humans being the third.\n\nHumans do not realize they are only the third most intelligent and are among the most ignorant and technologically backward people in the universe.History\nOrigins\n\nWhen the supercomputer Deep Thought announced the\xa0Ultimate Answer\xa0as Forty-Two after seven and a half million years of thought, it challenged\xa0Phouchg\xa0and\xa0Loonquawl\xa0to say what the\xa0Ultimate Question actually was. When they could not, Deep Thought designed a supercomputer that could give the Question, giving it its future name of the Earth.\n\nThe Magratheans were then hired to build the Earth, using a method of sucking matter through white holes to construct the vast planet-like computer. Slartibartfast designed the fjords of Norway, for which he won an award.\n\nPrehistoric times\nthumb|Golgafrincham Ark Fleet, Ship B, as seen in the 1981 TV series.\nThe Golgafrinchan Ark Fleet Ship B crash-landed on Earth, leaving\xa0Arthur Dent\xa0and\xa0Ford Prefect\xa0stranded in time.\nDestruction\nThe psychiatrist Gag Halfrunt thought that his career would cease if the Question were known. Therefore, he got the Vogons to destroy the supercomputer, with the apparent excuse of building a hyperspace bypass. The Vogons destroyed the Earth five minutes before the Question was due to be announced, thereby destroying ten million years worth of work.As told to Arthur Dent by Slartibartfast, in chapter 30 of the Douglas Adams novel The Hitchhiker\'s Guide to the Galaxy.Origins\n\nWhen the supercomputer Deep Thought announced the\xa0Ultimate Answer\xa0as Forty-Two after seven and a half million years of thought, it challenged\xa0Phouchg\xa0and\xa0Loonquawl\xa0to say what the\xa0Ultimate Question actually was. When they could not, Deep Thought designed a supercomputer that could give the Question, giving it its future name of the Earth.\n\nThe Magratheans were then hired to build the Earth, using a method of sucking matter through white holes to construct the vast planet-like computer. Slartibartfast designed the fjords of Norway, for which he won an award.Prehistoric times\nthumb|Golgafrincham Ark Fleet, Ship B, as seen in the 1981 TV series.\nThe Golgafrinchan Ark Fleet Ship B crash-landed on Earth, leaving\xa0Arthur Dent\xa0and\xa0Ford Prefect\xa0stranded in time.Destruction\nThe psychiatrist Gag Halfrunt thought that his career would cease if the Question were known. Therefore, he got the Vogons to destroy the supercomputer, with the apparent excuse of building a hyperspace bypass. The Vogons destroyed the Earth five minutes before the Question was due to be announced, thereby destroying ten million years worth of work.As told to Arthur Dent by Slartibartfast, in chapter 30 of the Douglas Adams novel The Hitchhiker\'s Guide to the Galaxy. Tri ...

# %%
scrape_list
# Out:
# [{'fn': 'data/series/the-hitchhiker-s-guide-to-the-galaxy.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy'},
#  {'fn': 'data/author-s/douglas-adams.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Douglas_Adams'},
#  {'fn': 'data/audiobook-narrator-s/stephen-fry.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Stephen_Fry'},
#  {'fn': 'data/followed-by/the-restaurant-at-the-end-of-the-universe.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/The_Restaurant_at_the_End_of_the_Universe'},
#  {'fn': 'data/followed-by/the-hitchhiker-s-guide-to-the-galaxy.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy'},
#  {'fn': 'data/followed-by/douglas-adams.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Douglas_Adams'},
#  {'fn': 'data/plot-summary/arthur-dent.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Arthur_Dent'},
#  {'fn': 'data/plot-summary/ford-prefect.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Ford_Prefect'},
#  {'fn': 'data/plot-summary/betelgeuse.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Betelgeuse'},
#  {'fn': 'data/plot-summary/earth.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Earth'},
#  {'fn': 'data/plot-summary/vogons.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Vogons'},
#  {'fn': 'data/plot-summary/vogons-ships.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Vogon_Constructor_Fleet'},
#  {'fn': 'data/plot-summary/heart-of-gold.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Heart_of_Gold'},
#  {'fn': 'data/plot-summary/zaphod-beeblebrox.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Zaphod_Beeblebrox'},
#  {'fn': 'data/plot-summary/trillian.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Trillian'},
#  {'fn': 'data/plot-summary/marvin.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Marvin'},
#  {'fn': 'data/plot-summary/magrathea.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Magrathea'},
#  {'fn': 'data/plot-summary/slartibartfast.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Slartibartfast'},
#  {'fn': 'data/plot-summary/hyper-intelligent-pan-dimensional-beings.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Mice'},
#  {'fn': 'data/plot-summary/deep-thought.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Deep_Thought'},
#  {'fn': 'data/plot-summary/42.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/42'},
#  {'fn': 'data/plot-summary/mice.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Frankie_and_Benjy'},
#  {'fn': 'data/plot-summary/shooty.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Shooty'},
#  {'fn': 'data/plot-summary/bang-bang.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Bang_Bang'},
#  {'fn': 'data/plot-summary/restaurant-at-the-end-of-the-universe.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Milliways'},
#  {'fn': 'data/main-characters/arthur-dent.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Arthur_Dent'},
#  {'fn': 'data/main-characters/ford-prefect.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Ford_Prefect'},
#  {'fn': 'data/main-characters/zaphod-beeblebrox.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Zaphod_Beeblebrox'},
#  {'fn': 'data/main-characters/trillian-astra.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Trillian_Astra'},
#  {'fn': 'data/main-characters/marvin.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Marvin'},
#  {'fn': 'data/minor-characters/mr-prosser.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Mr_Prosser'},
#  {'fn': 'data/minor-characters/barman.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Barman'},
#  {'fn': 'data/minor-characters/prostetnic-vogon-jeltz.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Prostetnic_Vogon_Jeltz'},
#  {'fn': 'data/minor-characters/eddie-the-computer.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Eddie_the_Computer'},
#  {'fn': 'data/minor-characters/frankie.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Frankie_and_Benjy'},
#  {'fn': 'data/minor-characters/benjy.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Frankie_and_Benjy'},
#  {'fn': 'data/minor-characters/whale.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Magrathean_sperm_whale'},
#  {'fn': 'data/minor-characters/bowl-of-petunias.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Agrajag'},
#  {'fn': 'data/minor-characters/slartibartfast.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Slartibartfast'},
#  {'fn': 'data/minor-characters/shooty.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Shooty'},
#  {'fn': 'data/minor-characters/bang-bang.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Bang_Bang'},
#  {'fn': 'data/minor-characters/fenchurch.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Fenchurch'},
#  {'fn': 'data/minor-characters/god.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/God'},
#  {'fn': 'data/minor-characters/oolon-colluphid.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Oolon_Colluphid'},
#  {'fn': 'data/minor-characters/genghis-khan.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Genghis_Khan'},
#  {'fn': 'data/minor-characters/eccentrica-gallumbits.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Eccentrica_Gallumbits'},
#  {'fn': 'data/minor-characters/paula-nancy-millstone-jennings.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Paula_Nancy_Millstone_Jennings'},
#  {'fn': 'data/minor-characters/grunthos-the-flatulent.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Grunthos_the_Flatulent'},
#  {'fn': 'data/minor-characters/deep-thought.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Deep_Thought'},
#  {'fn': 'data/minor-characters/lunkwill.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Lunkwill'},
#  {'fn': 'data/minor-characters/fook.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Fook'},
#  {'fn': 'data/minor-characters/loonquawl.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Loonquawl'},
#  {'fn': 'data/minor-characters/phouchg.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Phouchg'},
#  {'fn': 'data/minor-characters/majikthise.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Majikthise'},
#  {'fn': 'data/minor-characters/vroomfondel.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Vroomfondel'},
#  {'fn': 'data/minor-characters/milliard-gargantubrain.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Milliard_Gargantubrain'},
#  {'fn': 'data/minor-characters/googleplex-star-thinker.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Googleplex_Star_Thinker'},
#  {'fn': 'data/minor-characters/great-hyperlobic-omni-cognate-neutron-wrangler.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Great_Hyperlobic_Omni-Cognate_Neutron_Wrangler'},
#  {'fn': 'data/minor-characters/multicorticoid-perspicutron-titan-muller.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Multicorticoid_Perspicutron_Titan_Muller'},
#  {'fn': 'data/minor-characters/pondermatic.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Pondermatic'},
#  {'fn': 'data/minor-characters/veet-voojagig.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Veet_Voojagig'},
#  {'fn': 'data/minor-characters/emperor-of-the-galaxy.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Emperor_of_the_Galaxy'},
#  {'fn': 'data/minor-characters/yooden-vranx.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Yooden_Vranx'},
#  {'fn': 'data/devices/the-hitchhiker-s-guide-to-the-galaxy.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/The_Hitchhiker%27s_Guide_to_the_Galaxy_(travel_guide)'},
#  {'fn': 'data/devices/towel.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Towel'},
#  {'fn': 'data/devices/sub-etha-sens-o-matic.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Sub-Etha_Sens-O-Matic'},
#  {'fn': 'data/devices/electronic-thumb.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Electronic_Thumb'},
#  {'fn': 'data/devices/hyperspace.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Hyperspace'},
#  {'fn': 'data/devices/digital-watch.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Digital_watch'},
#  {'fn': 'data/devices/infinite-improbability-drive.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Infinite_Improbability_Drive'},
#  {'fn': 'data/devices/nutri-matic-drink-synthesizer.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Nutri-Matic_Drink_Synthesizer'},
#  {'fn': 'data/devices/kill-o-zap-gun.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Kill-o-Zap_Gun'},
#  {'fn': 'data/ships/heart-of-gold.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Heart_of_Gold'},
#  {'fn': 'data/ships/vogon-constructor-fleet.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Vogon_Constructor_Fleet'},
#  {'fn': 'data/places/earth.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Earth'},
#  {'fn': 'data/places/arthur-dent-s-house.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Arthur_Dent%27s_House'},
#  {'fn': 'data/places/horse-and-groom.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Horse_and_Groom'},
#  {'fn': 'data/places/damogran.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Damogran'},
#  {'fn': 'data/places/magrathea.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Magrathea'},
#  {'fn': 'data/places/guildford.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Guildford'},
#  {'fn': 'data/places/jaglan-beta.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Jaglan_Beta'},
#  {'fn': 'data/places/santraginus-v.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Santraginus_V'},
#  {'fn': 'data/places/kakrafoon-kappa.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Kakrafoon_Kappa'},
#  {'fn': 'data/places/betelgeuse-v.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Betelgeuse_V'},
#  {'fn': 'data/places/betelgeuse-vii.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Betelgeuse_VII'},
#  {'fn': 'data/places/squornshellous-zeta.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Squornshellous_Zeta'},
#  {'fn': 'data/places/eroticon-vi.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Eroticon_VI'},
#  {'fn': 'data/places/bethselamin.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Bethselamin'},
#  {'fn': 'data/places/vogsphere.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Vogsphere'},
#  {'fn': 'data/places/kria.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Kria'},
#  {'fn': 'data/places/traal.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Traal'},
#  {'fn': 'data/places/fallia.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Fallia'},
#  {'fn': 'data/places/seventh-galaxy-of-light-and-ingenuity.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Seventh_Galaxy_of_Light_and_Ingenuity'},
#  {'fn': 'data/places/dangrabad-beta.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Dangrabad_Beta'},
#  {'fn': 'data/places/poghril.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Poghril'},
#  {'fn': 'data/places/university-of-maximegalon.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/University_of_Maximegalon'},
#  {'fn': 'data/places/norway.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Norway'},
#  {'fn': 'data/places/blagulon-kappa.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Blagulon_Kappa'},
#  {'fn': 'data/races-and-species/human.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Human'},
#  {'fn': 'data/races-and-species/betelgeusian.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Betelgeusian'},
#  {'fn': 'data/races-and-species/vogon.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Vogon'},
#  {'fn': 'data/races-and-species/dentrassi.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Dentrassis'},
#  {'fn': 'data/races-and-species/babel-fish.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Babel_Fish'},
#  {'fn': 'data/races-and-species/scintillating-jeweled-scuttling-crab.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Scintillating_Jeweled_Scuttling_Crab'},
#  {'fn': 'data/races-and-species/damogran-frond-crested-eagle.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Damogran_Frond_Crested_Eagle'},
#  {'fn': 'data/races-and-species/hooloovoo.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Hooloovoo'},
#  {'fn': 'data/races-and-species/mouse.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Mouse'},
#  {'fn': 'data/races-and-species/magrathean.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Magrathean'},
#  {'fn': 'data/races-and-species/sperm-whale.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Magrathean_sperm_whale'},
#  {'fn': 'data/races-and-species/blagulon-kappa.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Blagulon_Kappa'},
#  {'fn': 'data/races-and-species/azgoth.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Azgoths_of_Kria'},
#  {'fn': 'data/races-and-species/dolphin.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Dolphin'},
#  {'fn': 'data/races-and-species/poghril.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Poghril'},
#  {'fn': 'data/races-and-species/ravenous-bugblatter-beast-of-traal.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Ravenous_Bugblatter_Beast_of_Traal'},
#  {'fn': 'data/races-and-species/arcturus.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Arcturus'},
#  {'fn': 'data/races-and-species/arcturan-megadonkey.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Arcturan_MegaDonkey'},
#  {'fn': 'data/races-and-species/g-gugvuntts.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/G%27Gugvuntts'},
#  {'fn': 'data/races-and-species/vl-hurgs.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Vl%27Hurgs'},
#  {'fn': 'data/publications/encyclopedia-galactica.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Encyclopedia_Galactica'},
#  {'fn': 'data/publications/where-god-went-wrong.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Where_God_Went_Wrong'},
#  {'fn': 'data/publications/some-more-of-god-s-greatest-mistakes.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Some_More_of_God%27s_Greatest_Mistakes'},
#  {'fn': 'data/publications/who-is-this-god-person-anyway.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Who_is_this_God_Person_Anyway%3F'},
#  {'fn': 'data/publications/well-that-about-wraps-it-up-for-god.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/Well_That_About_Wraps_It_Up_For_God'},
#  {'fn': 'data/publications/my-favourite-bathtime-gurgles.txt',
#   'href': 'https://hitchhikers.fandom.com/wiki/My_Favourite_Bathtime_Gurgles'}]

# %%
    f.write(content_el.text)

# %%
headers
# data/main-characters/arthur-dent.txt
# Should not save in dict, save directly to file

for header in headers:
    print(header.text)
    section_links = []
    for tag in header.find_next_siblings():
        print(tag.find_all("a"))
        
        #if tag.name == 'a':
        #    print(tag)

# %%
for header in headers:
    print(header.text)  # print the header text
    section_elements = []  # create an empty list to store the section elements
    next_sibling = header.find_next_sibling()
    while next_sibling and next_sibling.name not in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
        section_elements.append(next_sibling)
        next_sibling = next_sibling.find_next_sibling()
        # print the section elements
        # find the things -
    
    for element in section_elements:
        pass
        #print(element.text)
